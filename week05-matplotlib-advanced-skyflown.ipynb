# %% [markdown]
# # matplotlib 중급

# %% [markdown]
# ## 시스템 점검

# %%
import sys
sys.version
# Out:
# '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]'

# %%
sys.path
# Out:
# ['C:\\2023-A-DA',
#  'C:\\Users\\102\\anaconda3\\python39.zip',
#  'C:\\Users\\102\\anaconda3\\DLLs',
#  'C:\\Users\\102\\anaconda3\\lib',
#  'C:\\Users\\102\\anaconda3',
#  '',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\102\\.ipython']

# %% [markdown]
# ## plot() 복습
# - 한글처리

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([10, 20, 30, 40])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title('Line Plot')
plt.plot(range(1, 30, 7))
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1,2, 3, 4], [10, 20, 30, 40])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40])
plt.title('plotting')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40])
plt.title('plotting')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], label='ascending')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], label='descending')
plt.title('legend')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='skyblue', label='skyblue')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'pink', label='pink')
plt.title('color')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='r', linestyle='--', label='dashed')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'b', ls=':', label='dotted')
plt.title('linestyle')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='r', linestyle='--', marker='d', label='diamond')
plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'b', ls=':', marker='^', label='triangle up')
plt.title('marker')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 2))
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.plot([-2, -1, 0, 1, 2, 3], [20, 30, 15, 40, 45, 35], label='선 1')
plt.plot([-2, -1, 0, 1, 2, 3], [-25, 10, 35, 20, 15, 25], label='선 2')
plt.title('선 그래프 예제')
plt.xlabel('x축')
plt.ylabel('y축')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(7, 4))
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

x=np.linspace(-2*np.pi, 2*np.pi, 200)
plt.plot(x, np.sin(x)*10)
plt.plot(x, x**2)
plt.plot(x, 2*x**2 -3*x)

plt.grid(True)
plt.title('다양한 그래프')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist([1, 1, 2, 3, 4, 5,6, 6, 7, 8, 10])
plt.show()

# %%
import matplotlib.pyplot as plt

arrays, bins, patches = plt.hist([1, 1, 2, 3, 4, 5,6, 6, 7, 8, 10])
plt.show()

# %%
arrays
# Out:
# array([2., 1., 1., 1., 1., 2., 1., 1., 0., 1.])

# %%
bins
# Out:
# array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ])

# %%
import matplotlib.pyplot as plt
import numpy as np

arrays, bins, patches = plt.hist([1, 1, 2, 3, 4, 5,6, 6, 7, 8, 10], bins=np.arange(0.5, 11.5))
plt.show()

# %%
arrays
# Out:
# array([2., 1., 1., 1., 1., 2., 1., 1., 0., 1.])

# %%
bins
# Out:
# array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5])

# %%
import random
import matplotlib.pyplot as plt

dice =[]

for i in range(5):
    dice.append(random.randint(1, 6))
    
plt.hist(dice, bins=np.arange(0.5, 7.5))
plt.show()

# %%
import random
import matplotlib.pyplot as plt

dice =[]

for i in range(1000000):
    dice.append(random.randint(1, 6))
    
plt.hist(dice, bins=np.arange(0.5, 7.5))
plt.show()

# %%
import random
import matplotlib.pyplot as plt

result =[]
for i in range(13):
    result.append(random.randint(1, 1000))

print(sorted(result))
    
plt.boxplot(result)
plt.show()
# Out:
# [54, 60, 81, 91, 239, 604, 626, 635, 654, 711, 762, 967, 970]

# %%
import random
import matplotlib.pyplot as plt

result1 =[]
result2 =[]
for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))
    
plt.boxplot(result1)
plt.boxplot(result2)
plt.show()

# %%
import random
import matplotlib.pyplot as plt

result1 =[]
result2 =[]
for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))
    
plt.boxplot([result1, result2])
plt.show()

# %%
# !pip install koreanize-matplotlib
# Out:
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#      ---------------------------------------- 7.9/7.9 MB 15.4 MB/s eta 0:00:00
# Collecting matplotlib (from koreanize-matplotlib)
#   Downloading matplotlib-3.8.0-cp311-cp311-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 40.8 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib->koreanize-matplotlib)
#   Downloading contourpy-1.1.1-cp311-cp311-win_amd64.whl (480 kB)
#      ------------------------------------- 480.5/480.5 kB 29.4 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib->koreanize-matplotlib)
#   Downloading cycler-0.12.0-py3-none-any.whl (8.2 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->koreanize-matplotlib)
#   Downloading fonttools-4.43.0-cp311-cp311-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 45.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib->koreanize-matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#      ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\102\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->koreanize-matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\102\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->koreanize-matplotlib) (23.1)
# Collecting pillow>=6.2.0 (from matplotlib->koreanize-matplotlib)
#   Downloading Pillow-10.0.1-cp311-cp311-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 26.6 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib->koreanize-matplotlib)
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#      ---------------------------------------- 103.1/103.1 kB ? eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\102\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\102\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, koreanize-matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.0 fonttools-4.43.0 kiwisolver-1.4.5 koreanize-matplotlib-0.1.1 matplotlib-3.8.0 pillow-10.0.1 pyparsing-3.1.1
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: C:\Users\102\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-1, 0, 1, 2])
plt.title('그래프 제목', fontweight="bold")
plt.xlabel('간단한 그래프')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1484\2499138655.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 import koreanize_matplotlib
#       3
#       4 plt.plot([-1, 0, 1, 2])
#       5 plt.title('그래프 제목', fontweight="bold")
#
# ModuleNotFoundError: No module named 'koreanize_matplotlib'

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.plot(range(-20, 80), np.random.randn(100).cumsum(),
'r--')
plt.title('한글 점검');

# %%
fig = plt.figure(figsize=(15, 12))
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'),
figsize=(15, 12))
graph_title = '시험'
ax.set_title(f'{graph_title}')
ax.set_xlabel('야호 (Hz)', labelpad=20)
ax.set_ylabel('시간 (s)', labelpad=20)
ax.set_zlabel('이건 뭐지 (dB/Hz)', labelpad=20)
ax.view_init(20, 20)
plt.show()

# %%
ax1 = plt.subplot(2, 1, 1)
plt.plot(np.random.randint(1, 10, 10), 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2=plt.subplot(2, 1, 2)
plt.plot(np.arange(10), np.arange(10)*2, 'r.-')
plt.xlabel('timr (s)')
plt.ylabel('Unddamped')
print(ax2)

plt.tight_layout()
plt.show
# Out:
# AxesSubplot(0.125,0.53;0.775x0.35)
# AxesSubplot(0.125,0.11;0.775x0.35)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 3))
plt.subplot(2, 3, 1)
plt.subplot
# Out:
# <function matplotlib.pyplot.subplot(*args, **kwargs)>

# %% [markdown]
# ## plt.subplots()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2)

axes[0, 0].plot()
axes[0, 1].plot()
axes[1, 0].plot()
axes[1, 1].plot()

plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2)

axes[0, 0].plot([1, 2, 3, 4])
axes[0, 0].set_title("Subplot 1")

axes[0, 1].plot([4, 3, 2, 1])
axes[0, 1].set_title("Subplot 2")

axes[1, 0].hist([1, 2, 2, 3, 3, 3, 4, 4, 4, 4], bins=5)
axes[1, 0].set_title("Subplot 3")

axes[1, 1].scatter([1, 2, 3, 4], [4, 3, 2, 1])
axes[1, 1].set_title("Subplot 4")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)

axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %%
plt.subplots(2, 3, sharex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1484\12386526.py in <module>
# ----> 1 plt.subplots(2, 3, sharex)
#
# NameError: name 'sharex' is not defined

# %% [markdown]
# ## fig.add_subplot()

# %%
fig = plt.figure(figsize=(10, 8))
ax2=fig.add_subplot(2, 2, 2)
plt.plot(np.random.randn(50).cumsum(), 'k--')
ax3 = fig.add_subplot(2, 2, 3)

# %%
fig, axes = plt.subplots(2, 3, sharex=True, sharey=True, figsize=(8,6))
for i in range(2):
# Out:
#   File "C:\Users\102\AppData\Local\Temp\ipykernel_1484\1028829179.py", line 3
#
#     ^
# IndentationError: expected an indented block
