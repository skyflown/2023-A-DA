# %% [markdown]
# # matplotlib  중급

# %% [markdown]
# ### 시스템 점검

# %%
import sys
sys.version
# Out:
# '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]'

# %%
sys.path
# Out:
# ['C:\\Users\\LG',
#  'D:\\Users\\LG\\anaconda3\\python311.zip',
#  'D:\\Users\\LG\\anaconda3\\DLLs',
#  'D:\\Users\\LG\\anaconda3\\Lib',
#  'D:\\Users\\LG\\anaconda3',
#  '',
#  'D:\\Users\\LG\\anaconda3\\Lib\\site-packages',
#  'D:\\Users\\LG\\anaconda3\\Lib\\site-packages\\win32',
#  'D:\\Users\\LG\\anaconda3\\Lib\\site-packages\\win32\\lib',
#  'D:\\Users\\LG\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %% [markdown]
# ## ploting

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('font', family='Malgun Gothic')
mpl.rcParams['axes.unicode_minus']=False

plt.plot([1,2,3,4],[10,20,30,40])
plt.title('plotting')
plt.show()

# %% [markdown]
# ## figsize()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] =False

x= np.linspace(-2*np.pi,2*np.pi,200)
plt.plot(x,np.sin(x)*10)
plt.plot(x,x**2)
plt.plot(x,2 * x**2 - 3*x)

plt.grid(True)
plt.title('다양한그래프')
plt.show()

# %% [markdown]
# ## hist

# %%
import matplotlib.pyplot as plt

plt.hist([1,1,2,3,4,5,6,6,7,8,10])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

arrays, bins, patches = plt.hist([1,1,2,3,4,5,6,6,8,10],rwidth=0.9)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

arrays, bins, patches = plt.hist([1, 1, 2, 3, 4, 5, 6, 6, 8, 10], bins=np.arange(0.5,11.5))
plt.show()

# %%
arrays
# Out:
# array([2., 1., 1., 1., 1., 2., 0., 1., 0., 1.])

# %%
bins
# Out:
# array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5])

# %% [markdown]
# ## random

# %%
import random
random.randrange(1,6)
# Out:
# 2

# %%
import random as rd
dice=[]
for i in range(5):
    dice.append(rd.randint(1,6))
    
dice
# Out:
# [1, 4, 4, 1, 4]

# %% [markdown]
# ## 리스트 컴프리헨션

# %%
dice = [rd.randint(1,6) for i in range(5)]
dice
# Out:
# [4, 1, 4, 4, 2]

# %%
rd.choices(range(1,7), k=20)
# Out:
# [2, 1, 4, 3, 2, 6, 6, 5, 1, 2, 2, 1, 1, 5, 6, 6, 6, 5, 1, 6]

# %%
import random
import matplotlib.pyplot as plt

dice=[]

for i in range(1000):
    dice.append(random.randint(1,6))

plt.hist(dice, bins=np.arange(0.5,7.5))
plt.show()

# %%
import random
import matplotlib.pyplot as plt

dice=[]

for i in range(100000):
    dice.append(random.randint(1,6))

plt.hist(dice, bins=np.arange(0.5,7.5))
plt.show()

# %% [markdown]
# ## boxplot

# %%
import matplotlib.pyplot as plt
import random
result= []
for i in range(13):
    result.append(random.randint(1,1000))

print(sorted(result))

plt.boxplot(result)
plt.show()
# Out:
# [166, 208, 254, 299, 320, 329, 477, 605, 612, 634, 746, 856, 968]

# %%
import matplotlib.pyplot as plt
import random

result1= []
result2= []

for i in range(13):
    result1.append(random.randint(1,500))
    result2.append(random.randint(501,1000))

plt.boxplot([result1, result2])

plt.show()

# %% [markdown]
# ## plt.figure(figsize=(m,n))

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(0)

f1= plt.figure(figsize=(10,2))
plt.plot(np.random.randn(100))

plt.title("figure size:(10,2)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## plt.subplot

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,3))
plt.subplot(2,3,1)
plt.subplot(2,3,5)
plt.subplot(2,3,6)
# Out:
# <Axes: >

# %%
ax1 = plt.subplot(2,1,1)
plt.plot(np.random.randint(1,10,10),'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2= plt.subplot(2,1,2)
plt.plot(np.arange(10), np.arange(10)*2,'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# Axes(0.125,0.53;0.775x0.35)
# Axes(0.125,0.11;0.775x0.35)

# %%
import matplotlib.pyplot as plt

# fig, axes = plt.subplots(2,2)
plt.subplots(2,4)
# axes[0,0].plot()
# axes[0,1].plot()
# axes[1,0].plot()
# axes[1,1].plot()

plt.show()

# %%
import matplotlib.pyplot as plt

fig,axes = plt.subplots(2,2)
plt.figure(figsize=(6,4))

axes[0,0].plot([1,2,3,4])
axes[0,0].set_title("Subplot 1")

axes[0,1].plot([4,3,2,1])
axes[0,1].set_title("Subplot 2")

axes[1,0].hist([1,2,2,3,3,3,4,4,4,4])
axes[1,0].set_title("Subplot 3")

axes[1,1].scatter([1,2,3,4],[4,3,2,1])
axes[1,1].set_title("Subplot 4")
# Out:
# Text(0.5, 1.0, 'Subplot 4')

# %%
plt.subplots(2,3, sharex=True, sharey=True)
plt.show()

# %% [markdown]
# ## fig.add_subplot()

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(7,5))
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(7,5))
ax2 = fig.add_subplot(2,2,2)
plt.plot(np.random.randn(50).cumsum(), 'g--')
ax3 = fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50), 'm--')
